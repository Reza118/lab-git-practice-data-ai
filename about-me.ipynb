# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Reza Mokhtari"
reason = "AI Engineering combines software engineering with AI to solve real-world problems. With my background in software development and strong interest in mathematics, I want to build practical AI-powered applications and expand my skills in this field"
fun_fact = "I enjoy exploring the connection between mathematics, physics, software engineering, and AI. My goal for this course is to turn that interest into practical AI engineering skills and real-world projects"
print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Reza Mokhtari. I’m excited to learn because AI Engineering combines software engineering with AI to solve real-world problems. With my background in software development and strong interest in mathematics, I want to build practical AI-powered applications and expand my skills in this field. A fun fact about me is: I enjoy exploring the connection between mathematics, physics, software engineering, and AI. My goal for this course is to turn that interest into practical AI engineering skills and real-world projects.
